# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline

# %%
df = pd.read_csv(r"D:\archive\submission1.csv")
df
# Out:
#         Id      SalePrice
# 0     1461  156633.390588
# 1     1462  195762.895873
# 2     1463  217506.844296
# 3     1464  230249.357588
# 4     1465  240294.658327
# ...    ...            ...
# 1454  2915  113062.886515
# 1455  2916  112171.293701
# 1456  2917  187684.197911
# 1457  2918  161493.266053
# 1458  2919  296906.953976
#
# [1459 rows x 2 columns]

# %%
df.head()
# Out:
#      Id      SalePrice
# 0  1461  156633.390588
# 1  1462  195762.895873
# 2  1463  217506.844296
# 3  1464  230249.357588
# 4  1465  240294.658327

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['Id']],df.SalePrice)
# Out:
# LinearRegression()

# %%
xlabel = plt.xlabel('id')
ylabel = plt.ylabel('SalePrice')
plt.scatter(df.Id,df.SalePrice,color="green")

# %%
plt.scatter(df.SalePrice,df.Id,color='green')
xlabel = plt.xlabel('SalePrice')
ylabel = plt.ylabel('Id')

# %%
reg.coef_
# Out:
# array([-10.60697754])

# %%
reg.intercept_
# Out:
# 249516.05775382952

# %%
-10.60697754 * 2919 + 249516.05775382952
# Out:
# 218554.29031456952

# %%
reg.predict([[2919]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:461: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([218554.29030344])

# %%
reg.predict([[3000]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:461: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([217695.1251224])

# %%
reg.predict([[3500]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:461: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([212391.63635049])
